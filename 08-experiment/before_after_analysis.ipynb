# %% [markdown]
# # Simulated fix: before/after analysis
# Welch test and bootstrap confidence interval for battery-topic sentiment and volume.

# %%
import json, pandas as pd
result=json.load(open('outputs/before_after_results.json'))
result

# %% [markdown]
# ## So what?
# The simulation validates the measurement workflow, not causality. A real launch requires exposure denominators and a credible comparison group.
